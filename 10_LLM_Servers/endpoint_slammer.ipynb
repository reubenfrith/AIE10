# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/reuben-frith-6vo53hc/deployments/wuic9l5s"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# Ah— the age‑old tongue‑twister!  While no wood‑chuck’s lumber‑juggling prowess has ever been literally measured by an environmental scientist, the “official” estimate that’s made its way into popular folklore is that a wood‑chuck could move **about 7000 cubic feet of wood** (roughly 2,000 cubic meters) in a single day, assuming it had a mouth full of sticks and a healthy appetite for the job.
#
# That figure comes from a 1988 tongue‑in‑cheek study by two foresters who applied basic physics to a chuck’s dimensions—head width, arm reach, and so on—to convince a bored campus mascot troupe that a chuck was a highly efficient loader at most lumber yards.  In reality, gray‑bearded woodchucks (Marmota monax) are burrowers and herbivores; the “chewing” in their name is a cute homonym, not a literal chuck‑and‑store of logs.
#
# So, if you truly want to know how much wood a real wood‑chuck could chuck—well, until someone builds a miniature log‑pusher test rig, we’ll leave it to the tongue‑twister lore. And keep in mind: chucking wood is not a time‑well‑spent hobby for our burrowing friends—plant seedlings and leaves are their true diet!

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 18: A classic tongue‑twister, but there’s actually a fun answer!...
# Response 11: It turns out there’s no real “measurement” for how much wood...
# Response 20: I’m not sure what “Request 20” specifies. Could you let me k...
# Response 22: That old tongue‑twister has been the subject of some light‑h...
# Response 1: **Answer (Request 1)**
#
# There isn’t a definitive, scientif...
# Response 16: The classic question is a tongue‑twister, but it has been th...
# Response 7: A classic tongue‑twister, indeed!  The most common “answer” ...
# Response 3: A classic tongue‑twister answer is “as much as a woodchuck w...
# Response 23: It’s a classic tongue‑twister rather than a hard science que...
# Response 24: The line is a classic tongue‑twister, not a literal query—th...
# Response 12: Sure! The classic tongue‑twister goes:
# **“How much wood wo...
# Response 6: **Answer (Request 6)**
#
# The classic tongue‑twister is a bi...
# Response 14: A classic twist of tongue‑torquing – and a playful moot poin...
# Response 10: You’ve come to the right place for a classic tongue‑twister ...
# Response 5: The classic tongue‑twister has no scientific answer—but scie...
# Response 4: **The classic answer (and the “official” tongue‑twister resp...
# Response 13: **Answer (tongue‑twister style)**
# > *“A woodchuck would ch...
# Response 9: **Short answer:** Roughly **700 – 800 pounds** of wood, give...
# Response 15: A classic tongue‑twister rather than a literal fact! The jok...
# Response 21: **Ah, the classic wood‐chuck conundrum!**
#
# > *“How much wo...
# Response 19: Ah, the age‑old fa‑fa‑intest‑story of the wood‑chuck!  In tr...
# Response 8: ### The classic riddle, taken seriously (and slightly tongue...
# Response 2: Ah, the classic tongue‑tied riddle that has stumped poets, c...
# Response 17: Ah, the classic tongue‑twister made spectacularly literal! 🎤...
